# %% [markdown]
# <a href="https://colab.research.google.com/github/pthammaneni041218/HDS-5210/blob/main/FINAL/Final_Project_diabetes_Praveen.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img src="https://www.slu.edu/marcom/tools-downloads/-img/billiken/slu-billiken-rgb.png" width="400" height="400">
#
# <img src="https://www.slu.edu/marcom/tools-downloads/-img/hpgg/slu-hpgg-blue-rgb.png" width="400" height="40">

# %% [markdown]
# # **FINAL PROJECT 2024**

# %% [markdown]
# # Ouline of the Project

# %% [markdown]
# The project begins by defining the central problem, which focuses on identifying factors that contribute to a healthy lifestyle using advanced data analysis techniques. This sets the stage for a comprehensive exploration of the relationship between lifestyle choices and overall well-being.
#
# The abstract provides a concise overview of the project's goal: to uncover actionable insights that can empower individuals to make informed decisions about their health and promote a balanced lifestyle. This serves as a guiding framework for the subsequent analysis.
#
# The purpose of the project delves into its significance and relevance. It highlights the potential for meaningful contributions to individual well-being and public health by aligning the research with broader health and wellness objectives. The anticipated benefits include enhancing quality of life and providing evidence-based guidance for healthier living.
#
# An essential component of the project is an overview of the datasets used. This section describes the source, format, and characteristics of the data, offering readers a foundational understanding of the resources that underpin the analysis.
#
# A detailed summary of the dataset’s columns follows, explaining the key variables and their roles in the study. This provides context for understanding how the data supports the project’s objectives and informs the analysis.
#
# Data preprocessing is described in detail, emphasizing the importance of ensuring accuracy and reliability. Steps such as cleaning the data, addressing missing values, managing outliers, and standardizing variables are discussed to provide transparency and ensure the robustness of the findings.
#
# The analysis section presents the results of the data exploration and interpretation. Visualizations and statistical findings illustrate the insights derived from the preprocessed data. Each insight is explained thoroughly, focusing on its implications for fostering a healthy lifestyle and addressing the project's central objectives.
#
# Finally, the conclusion summarizes the key findings and discusses their implications for health and well-being. This section evaluates the success of the project in achieving its goals and offers recommendations for future research or enhancements to the study.

# %% [markdown]
# # Problem Statement

# %% [markdown]
# The problem this project addresses is identifying key factors that contribute to a healthy lifestyle through lessons learned in this class.

# %% [markdown]
# # Abstract

# %% [markdown]
# This project aims to utilize techniques learned in this class to derive meaningful insights and identify key trends related to healthy living. By focusing on factors and patterns that contribute to overall well-being, the study employs statistical analysis and data visualization to uncover actionable information. The findings are intended to empower individuals with evidence-based guidance for making informed lifestyle decisions. Beyond identifying correlations within the data, the project seeks to offer practical recommendations that enhance understanding of the essential components of a healthy and balanced life.

# %% [markdown]
# # Purpose

# %% [markdown]
# This project is significant because of its potential to address key aspects of public health and individual well-being, making it highly relevant and impactful.
#
# Firstly, it supports broader public health objectives by focusing on elements that encourage healthier lifestyles. In an era characterized by fast-paced living and widespread sedentary habits, promoting and understanding healthy practices is vital for disease prevention and enhancing overall quality of life.
#
# Secondly, the project aims to empower individuals by providing actionable insights that enable informed lifestyle choices. This guidance can lead to improved personal health outcomes and a reduction in healthcare demands, fostering greater individual autonomy in managing health.
#
# Additionally, the project emphasizes the importance of data-driven decision-making by utilizing advanced analytics to identify patterns and trends in health-related data. This evidence-based approach promotes proactive health management and highlights opportunities for early, preventive measures to address potential health issues.
#
# Furthermore, the project adopts a comprehensive perspective on well-being, encompassing not only physical health but also mental and emotional aspects. By acknowledging the interconnectedness of these dimensions, it seeks to provide a holistic framework for enhancing overall wellness.
#
# Lastly, the insights generated have the potential to drive effective lifestyle interventions, such as educational initiatives, policy reforms, or tailored health recommendations. These efforts aim to encourage positive behavioral changes and support long-term health improvements.
#
# In essence, this project represents a valuable contribution to advancing health and well-being. By merging robust data analysis with practical solutions, it seeks to make a meaningful difference for individuals and the wider public health landscape.

# %% [markdown]
# # Datasets of the Project

# %% [markdown]
# 1. https://www4.stat.ncsu.edu/~boos/var.select/diabetes.tab.txt
#   - Diabetes data for a sample of 442 observations
#   The source of this data is stat.ncsu.edu.
#   It contains 10 variables and a Y variable. There are no missing data.
#
# 2. https://www.kaggle.com/datasets/aniketmohan30/pimadiabetes
#   - This dataset, from the National Institute of Diabetes and Digestive and Kidney Diseases(originally), aims to predict diabetes in Pima Indian women aged 21 and older based on diagnostic measurements.
#
# 3. https://github.com/krishnakishore999/Diabetes_Prediction/blob/main/diabetes.csv
#  - This dataset was originally used to predict wheter a woman suffers with diabetes or not based on the woman's number of pregnancies, BP, BMI, age etc in a complex project.
#
# 4. https://www.kaggle.com/datasets/iammustafatz/diabetes-prediction-dataset/data
#   - EHRs are the primary source of data for this dataset. It has 9 columns and 100000 observations

# %% [markdown]
# # Datasets Reading

# %%
# Import
from tabulate import tabulate
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Reading files
xlsx = pd.read_excel('pima-data.xlsx', sheet_name='forExport')
txt = pd.read_csv('diabetes1.txt', delimiter='\t')
csv0 = pd.read_csv('diabetes.csv')
csv = pd.read_csv('diabetes2.csv')

# %%
xlsx.columns
# Out:
# Index(['num_preg', 'glucose_conc', 'diastolic_bp', 'thickness', 'insulin',
#        'bmi', 'diab_pred', 'age', 'skin', 'diabetes'],
#       dtype='object')

# %% [markdown]
# Dataset 1:
# - **num_preg:** Number of pregnancies the individual has experienced.
# - **glucose_conc:** Glucose concentration in the blood measured in mg/dL.
# - **diastolic_bp:** Diastolic blood pressure measured in mm Hg.
# - **thickness:** Thickness of skinfold measured in millimeters.
# - **Insulin:** Insulin level measured in mU/mL.
# - **bmi:** Body Mass Index (BMI)
# - **diab_pred:** A function that scores the likelihood of diabetes based on family history.
# - **age:** years a person has lived since birth
# - **diabetes:** Condition

# %%
txt.columns
# Out:
# Index(['AGE', 'SEX', 'BMI', 'BP', 'S1', 'S2', 'S3', 'S4', 'S5', 'S6', 'Y'], dtype='object')

# %% [markdown]
# Dataset 2:
# - **AGE:** years a person has lived since birth
# - **SEX:** male or female
# - **BMI:** body Mass Index (BMI)
# - **BP:** high blood pressure
# - **S1:** tc, T-Cells (a type of white blood cells)
# - **S2:** ldl, low-density lipoproteins
# - **S3:** hdl, high-density lipoproteins
# - **S4:** tch, thyroid stimulating hormone
# - **S5:** ltg, lamotrigine
# - **S6:** glu, blood sugar level
# - **Y:** response

# %%
csv0.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %% [markdown]
# Dataset 3:
# - **Pregnancies:** Number of pregnancies the individual has experienced.
# - **Glucose:** Glucose concentration in the blood measured in mg/dL.
# - **BloodPressure:** Diastolic blood pressure measured in mm Hg.
# - **SkinThickness:** Thickness of skinfold measured in millimeters.
# - **Insulin:** Insulin level measured in mU/mL.
# - **DiabetesPedigreeFunction:** A function that scores the likelihood of diabetes based on family history.

# %%
csv.columns
# Out:
# Index(['gender', 'age', 'hypertension', 'heart_disease', 'smoking_history',
#        'bmi', 'HbA1c_level', 'blood_glucose_level', 'diabetes'],
#       dtype='object')

# %% [markdown]
# Dataset 4:
# - **gender:** Male or female classification.
# - **age:** Individual's age in years.
# - **hypertension:** Presence of high blood pressure.
# - **heart_disease:** Any cardiovascular conditions.
# - **smoking_history:** Past or current tobacco use.
# - **bmi:** Body Mass Index, indicating weight status.
# - **HbA1c_level:** Average blood sugar over 2–3 months.
# - **blood_glucose_level:** Current blood sugar concentration.
# - **diabetes:** Chronic condition of elevated blood sugar.

# %% [markdown]
# # Functions

# %%
# Functions
def print_dataframes(df1, df2, df3, df4):
    """
    Print the head of three DataFrames in a tabular format.

    Parameters:
    - df1, df2, df3 (DataFrame): The three DataFrames to be printed.
    """
    print("DataFrame 1:")
    print(tabulate(df1.head(), headers='keys', tablefmt='fancy_grid'))

    print("\nDataFrame 2:")
    print(tabulate(df2.head(), headers='keys', tablefmt='fancy_grid'))

    print("\nDataFrame 3:")
    print(tabulate(df3.head(), headers='keys', tablefmt='fancy_grid'))

    print("\nDataFrame 4:")
    print(tabulate(df4.head(), headers='keys', tablefmt='fancy_grid'))

def count_unique_values(dataframe):
    """
    Check the number of unique values for columns of type int64 in the given DataFrame.
    """
    return dataframe.select_dtypes(include='int64').nunique()

def check_null_values(dataset):
    """
    Print the number of null values for each column in the given dataset.

    """

    for col in dataset.columns:
        print('{} has {} null values'.format(col, dataset[col].isnull().sum()))

def normalize_columns(dataframe):
    """
    Normalize the column names in the given DataFrame by converting them to lowercase,
    excluding the first letter.

    """

    dataframe.columns = [col[:1] + col[1:].lower() for col in dataframe.columns]

# %% [markdown]
# # Data Transformation

# %%
# Calling the function to print three DataFrames: csv, xlsx, and txt
print_dataframes(csv, xlsx, txt, csv0)
# Out:
# DataFrame 1:
# ╒════╤══════════╤═══════╤════════════════╤═════════════════╤═══════════════════╤═══════╤═══════════════╤═══════════════════════╤════════════╕
# │    │ gender   │   age │   hypertension │   heart_disease │ smoking_history   │   bmi │   HbA1c_level │   blood_glucose_level │   diabetes │
# ╞════╪══════════╪═══════╪════════════════╪═════════════════╪═══════════════════╪═══════╪═══════════════╪═══════════════════════╪════════════╡
# │  0 │ Female   │    80 │              0 │               1 │ never             │ 25.19 │           6.6 │                   140 │          0 │
# ├────┼──────────┼───────┼────────────────┼─────────────────┼───────────────────┼───────┼───────────────┼───────────────────────┼────────────┤
# │  1 │ Female   │    54 │              0 │               0 │ No Info           │ 27.32 │           6.6 │                    80 │          0 │
# ├────┼──────────┼───────┼────────────────┼─────────────────┼───────────────────┼───────┼───────────────┼───────────────────────┼────────────┤
# │  2 │ Male     │    28 │              0 │               0 │ never             │ 27.32 │           5.7 │                   158 │          0 │
# ├────┼──────────┼───────┼────────────────┼─────────────────┼───────────────────┼───────┼───────────────┼───────────────────────┼────────────┤
# │  3 │ Female   │    36 │              0 │               0 │ current           │ 23.45 │           5   │                   155 │          0 │
# ├────┼──────────┼───────┼────────────────┼─────────────────┼───────────────────┼───────┼───────────────┼───────────────────────┼────────────┤
# │  4 │ Male     │    76 │              1 │               1 │ current           │ 20.14 │           4.8 │                   155 │          0 │
# ╘════╧══════════╧═══════╧════════════════╧═════════════════╧═══════════════════╧═══════╧═══════════════╧═══════════════════════╧════════════╛
#
# DataFrame 2:
# ╒════╤════════════╤════════════════╤════════════════╤═════════════╤═══════════╤═══════╤═════════════╤═══════╤════════╤════════════╕
# │    │   num_preg │   glucose_conc │   diastolic_bp │   thickness │   insulin │   bmi │   diab_pred │   age │   skin │ diabetes   │
# ╞════╪════════════╪════════════════╪════════════════╪═════════════╪═══════════╪═══════╪═════════════╪═══════╪════════╪════════════╡
# │  0 │          6 │            148 │             72 │          35 │         0 │  33.6 │       0.627 │    50 │ 1.379  │ True       │
# ├────┼────────────┼────────────────┼────────────────┼─────────────┼───────────┼───────┼─────────────┼───────┼────────┼────────────┤
# │  1 │          1 │             85 │             66 │          29 │         0 │  26.6 │       0.351 │    31 │ 1.1426 │ False      │
# ├────┼────────────┼────────────────┼────────────────┼─────────────┼───────────┼───────┼─────────────┼───────┼────────┼────────────┤
# │  2 │          8 │            183 │             64 │           0 │         0 │  23.3 │       0.672 │    32 │ 0      │ True       │
# ├────┼────────────┼────────────────┼────────────────┼─────────────┼───────────┼───────┼─────────────┼───────┼────────┼────────────┤
# │  3 │          1 │             89 │             66 │          23 │        94 │  28.1 │       0.167 │    21 │ 0.9062 │ False      │
# ├────┼────────────┼────────────────┼────────────────┼─────────────┼───────────┼───────┼─────────────┼───────┼────────┼────────────┤
# │  4 │          0 │            137 │             40 │          35 │       168 │  43.1 │       2.288 │    33 │ 1.379  │ True       │
# ╘════╧════════════╧════════════════╧════════════════╧═════════════╧═══════════╧═══════╧═════════════╧═══════╧════════╧════════════╛
#
# DataFrame 3:
# ╒════╤═══════╤═══════╤═══════╤══════╤══════╤═══════╤══════╤══════╤════════╤══════╤═════╕
# │    │   AGE │   SEX │   BMI │   BP │   S1 │    S2 │   S3 │   S4 │     S5 │   S6 │   Y │
# ╞════╪═══════╪═══════╪═══════╪══════╪══════╪═══════╪══════╪══════╪════════╪══════╪═════╡
# │  0 │    59 │     2 │  32.1 │  101 │  157 │  93.2 │   38 │    4 │ 4.8598 │   87 │ 151 │
# ├────┼───────┼───────┼───────┼──────┼──────┼───────┼──────┼──────┼────────┼──────┼─────┤
# │  1 │    48 │     1 │  21.6 │   87 │  183 │ 103.2 │   70 │    3 │ 3.8918 │   69 │  75 │
# ├────┼───────┼───────┼───────┼──────┼──────┼───────┼──────┼──────┼────────┼──────┼─────┤
# │  2 │    72 │     2 │  30.5 │   93 │  156 │  93.6 │   41 │    4 │ 4.6728 │   85 │ 141 │
# ├────┼───────┼───────┼───────┼──────┼──────┼───────┼──────┼──────┼────────┼──────┼─────┤
# │  3 │    24 │     1 │  25.3 │   84 │  198 │ 131.4 │   40 │    5 │ 4.8903 │   89 │ 206 │
# ├────┼───────┼───────┼───────┼──────┼──────┼───────┼──────┼──────┼────────┼──────┼─────┤
# │  4 │    50 │     1 │  23   │  101 │  192 │ 125.4 │   52 │    4 │ 4.2905 │   80 │ 135 │
# ╘════╧═══════╧═══════╧═══════╧══════╧══════╧═══════╧══════╧══════╧════════╧══════╧═════╛
#
# DataFrame 4:
# ╒════╤═══════════════╤═══════════╤═════════════════╤═════════════════╤═══════════╤═══════╤════════════════════════════╤═══════╤═══════════╕
# │    │   Pregnancies │   Glucose │   BloodPressure │   SkinThickness │   Insulin │   BMI │   DiabetesPedigreeFunction │   Age │   Outcome │
# ╞════╪═══════════════╪═══════════╪═════════════════╪═════════════════╪═══════════╪═══════╪════════════════════════════╪═══════╪═══════════╡
# │  0 │             6 │       148 │              72 │              35 │         0 │  33.6 │                      0.627 │    50 │         1 │
# ├────┼───────────────┼───────────┼─────────────────┼─────────────────┼───────────┼───────┼────────────────────────────┼───────┼───────────┤
# │  1 │             1 │        85 │              66 │              29 │         0 │  26.6 │                      0.351 │    31 │         0 │
# ├────┼───────────────┼───────────┼─────────────────┼─────────────────┼───────────┼───────┼────────────────────────────┼───────┼───────────┤
# │  2 │             8 │       183 │              64 │               0 │         0 │  23.3 │                      0.672 │    32 │         1 │
# ├────┼───────────────┼───────────┼─────────────────┼─────────────────┼───────────┼───────┼────────────────────────────┼───────┼───────────┤
# │  3 │             1 │        89 │              66 │              23 │        94 │  28.1 │                      0.167 │    21 │         0 │
# ├────┼───────────────┼───────────┼─────────────────┼─────────────────┼───────────┼───────┼────────────────────────────┼───────┼───────────┤
# │  4 │             0 │       137 │              40 │              35 │       168 │  43.1 │                      2.288 │    33 │         1 │
# ╘════╧═══════════════╧═══════════╧═════════════════╧═════════════════╧═══════════╧═══════╧════════════════════════════╧═══════╧═══════════╛

# %%
# Printing the shape
xlsx.shape
# Out:
# (768, 10)

# %%
csv.shape
# Out:
# (100000, 9)

# %%
csv0.shape
# Out:
# (768, 9)

# %%
txt.shape
# Out:
# (442, 11)

# %%
# Printing the information about the DataFrame
xlsx.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   num_preg      768 non-null    int64
#  1   glucose_conc  768 non-null    int64
#  2   diastolic_bp  768 non-null    int64
#  3   thickness     768 non-null    int64
#  4   insulin       768 non-null    int64
#  5   bmi           768 non-null    float64
#  6   diab_pred     768 non-null    float64
#  7   age           768 non-null    int64
#  8   skin          768 non-null    float64
#  9   diabetes      768 non-null    bool
# dtypes: bool(1), float64(3), int64(6)
# memory usage: 54.9 KB

# %%
txt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 442 entries, 0 to 441
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   AGE     442 non-null    int64
#  1   SEX     442 non-null    int64
#  2   BMI     442 non-null    float64
#  3   BP      442 non-null    float64
#  4   S1      442 non-null    int64
#  5   S2      442 non-null    float64
#  6   S3      442 non-null    float64
#  7   S4      442 non-null    float64
#  8   S5      442 non-null    float64
#  9   S6      442 non-null    int64
#  10  Y       442 non-null    int64
# dtypes: float64(6), int64(5)
# memory usage: 38.1 KB

# %%
csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 9 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   gender               100000 non-null  object
#  1   age                  100000 non-null  float64
#  2   hypertension         100000 non-null  int64
#  3   heart_disease        100000 non-null  int64
#  4   smoking_history      100000 non-null  object
#  5   bmi                  100000 non-null  float64
#  6   HbA1c_level          100000 non-null  float64
#  7   blood_glucose_level  100000 non-null  int64
#  8   diabetes             100000 non-null  int64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 6.9+ MB

# %%
# basic statistic details about the data (note only numerical columns would be displayed here unless parameter include="all")
xlsx.describe()
# Out:
#          num_preg  glucose_conc  diastolic_bp   thickness     insulin  \
# count  768.000000    768.000000    768.000000  768.000000  768.000000
# mean     3.845052    120.894531     69.105469   20.536458   79.799479
# std      3.369578     31.972618     19.355807   15.952218  115.244002
# min      0.000000      0.000000      0.000000    0.000000    0.000000
# 25%      1.000000     99.000000     62.000000    0.000000    0.000000
# 50%      3.000000    117.000000     72.000000   23.000000   30.500000
# 75%      6.000000    140.250000     80.000000   32.000000  127.250000
# max     17.000000    199.000000    122.000000   99.000000  846.000000
#
#               bmi   diab_pred         age        skin
# count  768.000000  768.000000  768.000000  768.000000
# mean    31.992578    0.471876   33.240885    0.809136
# std      7.884160    0.331329   11.760232    0.628517
# min      0.000000    0.078000   21.000000    0.000000
# 25%     27.300000    0.243750   24.000000    0.000000
# 50%     32.000000    0.372500   29.000000    0.906200
# 75%     36.600000    0.626250   41.000000    1.260800
# max     67.100000    2.420000   81.000000    3.900600

# %%
txt.describe()
# Out:
#               AGE         SEX         BMI          BP          S1          S2  \
# count  442.000000  442.000000  442.000000  442.000000  442.000000  442.000000
# mean    48.518100    1.468326   26.375792   94.647014  189.140271  115.439140
# std     13.109028    0.499561    4.418122   13.831283   34.608052   30.413081
# min     19.000000    1.000000   18.000000   62.000000   97.000000   41.600000
# 25%     38.250000    1.000000   23.200000   84.000000  164.250000   96.050000
# 50%     50.000000    1.000000   25.700000   93.000000  186.000000  113.000000
# 75%     59.000000    2.000000   29.275000  105.000000  209.750000  134.500000
# max     79.000000    2.000000   42.200000  133.000000  301.000000  242.400000
#
#                S3          S4          S5          S6           Y
# count  442.000000  442.000000  442.000000  442.000000  442.000000
# mean    49.788462    4.070249    4.641411   91.260181  152.133484
# std     12.934202    1.290450    0.522391   11.496335   77.093005
# min     22.000000    2.000000    3.258100   58.000000   25.000000
# 25%     40.250000    3.000000    4.276700   83.250000   87.000000
# 50%     48.000000    4.000000    4.620050   91.000000  140.500000
# 75%     57.750000    5.000000    4.997200   98.000000  211.500000
# max     99.000000    9.090000    6.107000  124.000000  346.000000

# %%
csv.describe()
# Out:
#                  age  hypertension  heart_disease            bmi  \
# count  100000.000000  100000.00000  100000.000000  100000.000000
# mean       41.885856       0.07485       0.039420      27.320767
# std        22.516840       0.26315       0.194593       6.636783
# min         0.080000       0.00000       0.000000      10.010000
# 25%        24.000000       0.00000       0.000000      23.630000
# 50%        43.000000       0.00000       0.000000      27.320000
# 75%        60.000000       0.00000       0.000000      29.580000
# max        80.000000       1.00000       1.000000      95.690000
#
#          HbA1c_level  blood_glucose_level       diabetes
# count  100000.000000        100000.000000  100000.000000
# mean        5.527507           138.058060       0.085000
# std         1.070672            40.708136       0.278883
# min         3.500000            80.000000       0.000000
# 25%         4.800000           100.000000       0.000000
# 50%         5.800000           140.000000       0.000000
# 75%         6.200000           159.000000       0.000000
# max         9.000000           300.000000       1.000000

# %%
# Removing
xlsx.drop_duplicates(inplace=True)
csv.drop_duplicates(inplace=True)
csv0.drop_duplicates(inplace=True)
txt.drop_duplicates(inplace=True)

# Duplicated rows
print(xlsx.duplicated().sum())
print(txt.duplicated().sum())
print(csv.duplicated().sum())
print(csv0.duplicated().sum())
# Out:
# 0
# 0
# 0
# 0

# %%
# Calling the previously defined function to check null values
check_null_values(xlsx)
# Out:
# num_preg has 0 null values
# glucose_conc has 0 null values
# diastolic_bp has 0 null values
# thickness has 0 null values
# insulin has 0 null values
# bmi has 0 null values
# diab_pred has 0 null values
# age has 0 null values
# skin has 0 null values
# diabetes has 0 null values

# %%
check_null_values(csv)
# Out:
# gender has 0 null values
# age has 0 null values
# hypertension has 0 null values
# heart_disease has 0 null values
# smoking_history has 0 null values
# bmi has 0 null values
# HbA1c_level has 0 null values
# blood_glucose_level has 0 null values
# diabetes has 0 null values

# %%
check_null_values(csv0)
# Out:
# Pregnancies has 0 null values
# Glucose has 0 null values
# BloodPressure has 0 null values
# SkinThickness has 0 null values
# Insulin has 0 null values
# BMI has 0 null values
# DiabetesPedigreeFunction has 0 null values
# Age has 0 null values
# Outcome has 0 null values

# %%
check_null_values(txt)
# Out:
# AGE has 0 null values
# SEX has 0 null values
# BMI has 0 null values
# BP has 0 null values
# S1 has 0 null values
# S2 has 0 null values
# S3 has 0 null values
# S4 has 0 null values
# S5 has 0 null values
# S6 has 0 null values
# Y has 0 null values

# %%
# Describing the object columns in the csv DataFrame
csv.describe(include='object')
# Out:
#         gender smoking_history
# count    96146           96146
# unique       3               6
# top     Female           never
# freq     56161           34398

# %%
# Calling the previously defined function to count unique int values in each column of the sDataFrame
count_unique_values(csv)
# Out:
# hypertension            2
# heart_disease           2
# blood_glucose_level    18
# diabetes                2
# dtype: int64

# %%
count_unique_values(csv0)
# Out:
# Pregnancies       17
# Glucose          136
# BloodPressure     47
# SkinThickness     51
# Insulin          186
# Age               52
# Outcome            2
# dtype: int64

# %%
count_unique_values(xlsx)
# Out:
# num_preg         17
# glucose_conc    136
# diastolic_bp     47
# thickness        51
# insulin         186
# age              52
# dtype: int64

# %%
count_unique_values(txt)
# Out:
# AGE     58
# SEX      2
# S1     141
# S6      56
# Y      214
# dtype: int64

# %%
xlsx.columns = ['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
       'BMI', 'DiabetesPedigreeFunction', 'Age','Skin', 'Outcome']

# %%
# Initializing empty lists to store numeric and non-numeric column names for csv DataFrame
num_col_csv = []
non_num_col_csv = []

# Iterating through columns in csv DataFrame
for column in csv.columns:
    # Checking if the column is numeric
    if pd.api.types.is_numeric_dtype(csv[column]):
        # Checking if the numeric column has less than 2 unique values (considered non-numeric)
        if csv[column].nunique() < 2:
            non_num_col_csv.append(column)
        else:
            num_col_csv.append(column)
    # If the column is non-numeric
    else:
        non_num_col_csv.append(column)

# %%
print(num_col_csv)
print(non_num_col_csv)
# Out:
# ['age', 'hypertension', 'heart_disease', 'bmi', 'HbA1c_level', 'blood_glucose_level', 'diabetes']
# ['gender', 'smoking_history']

# %%
# Calling the previously defined function to normalize columns
# This makes by converting them to lowercase, excluding the first letter.
normalize_columns(csv)
normalize_columns(txt)
normalize_columns(xlsx)
normalize_columns(csv0)

# %%
print_dataframes(csv, xlsx, txt, csv0)
# Out:
# DataFrame 1:
# ╒════╤══════════╤═══════╤════════════════╤═════════════════╤═══════════════════╤═══════╤═══════════════╤═══════════════════════╤════════════╕
# │    │ gender   │   age │   hypertension │   heart_disease │ smoking_history   │   bmi │   Hba1c_level │   blood_glucose_level │   diabetes │
# ╞════╪══════════╪═══════╪════════════════╪═════════════════╪═══════════════════╪═══════╪═══════════════╪═══════════════════════╪════════════╡
# │  0 │ Female   │    80 │              0 │               1 │ never             │ 25.19 │           6.6 │                   140 │          0 │
# ├────┼──────────┼───────┼────────────────┼─────────────────┼───────────────────┼───────┼───────────────┼───────────────────────┼────────────┤
# │  1 │ Female   │    54 │              0 │               0 │ No Info           │ 27.32 │           6.6 │                    80 │          0 │
# ├────┼──────────┼───────┼────────────────┼─────────────────┼───────────────────┼───────┼───────────────┼───────────────────────┼────────────┤
# │  2 │ Male     │    28 │              0 │               0 │ never             │ 27.32 │           5.7 │                   158 │          0 │
# ├────┼──────────┼───────┼────────────────┼─────────────────┼───────────────────┼───────┼───────────────┼───────────────────────┼────────────┤
# │  3 │ Female   │    36 │              0 │               0 │ current           │ 23.45 │           5   │                   155 │          0 │
# ├────┼──────────┼───────┼────────────────┼─────────────────┼───────────────────┼───────┼───────────────┼───────────────────────┼────────────┤
# │  4 │ Male     │    76 │              1 │               1 │ current           │ 20.14 │           4.8 │                   155 │          0 │
# ╘════╧══════════╧═══════╧════════════════╧═════════════════╧═══════════════════╧═══════╧═══════════════╧═══════════════════════╧════════════╛
#
# DataFrame 2:
# ╒════╤═══════════════╤═══════════╤═════════════════╤═════════════════╤═══════════╤═══════╤════════════════════════════╤═══════╤════════╤═══════════╕
# │    │   Pregnancies │   Glucose │   Bloodpressure │   Skinthickness │   Insulin │   Bmi │   Diabetespedigreefunction │   Age │   Skin │ Outcome   │
# ╞════╪═══════════════╪═══════════╪═════════════════╪═════════════════╪═══════════╪═══════╪════════════════════════════╪═══════╪════════╪═══════════╡
# │  0 │             6 │       148 │              72 │              35 │         0 │  33.6 │                      0.627 │    50 │ 1.379  │ True      │
# ├────┼───────────────┼───────────┼─────────────────┼─────────────────┼───────────┼───────┼────────────────────────────┼───────┼────────┼───────────┤
# │  1 │             1 │        85 │              66 │              29 │         0 │  26.6 │                      0.351 │    31 │ 1.1426 │ False     │
# ├────┼───────────────┼───────────┼─────────────────┼─────────────────┼───────────┼───────┼────────────────────────────┼───────┼────────┼───────────┤
# │  2 │             8 │       183 │              64 │               0 │         0 │  23.3 │                      0.672 │    32 │ 0      │ True      │
# ├────┼───────────────┼───────────┼─────────────────┼─────────────────┼───────────┼───────┼────────────────────────────┼───────┼────────┼───────────┤
# │  3 │             1 │        89 │              66 │              23 │        94 │  28.1 │                      0.167 │    21 │ 0.9062 │ False     │
# ├────┼───────────────┼───────────┼─────────────────┼─────────────────┼───────────┼───────┼────────────────────────────┼───────┼────────┼───────────┤
# │  4 │             0 │       137 │              40 │              35 │       168 │  43.1 │                      2.288 │    33 │ 1.379  │ True      │
# ╘════╧═══════════════╧═══════════╧═════════════════╧═════════════════╧═══════════╧═══════╧════════════════════════════╧═══════╧════════╧═══════════╛
#
# DataFrame 3:
# ╒════╤═══════╤═══════╤═══════╤══════╤══════╤═══════╤══════╤══════╤════════╤══════╤═════╕
# │    │   Age │   Sex │   Bmi │   Bp │   S1 │    S2 │   S3 │   S4 │     S5 │   S6 │   Y │
# ╞════╪═══════╪═══════╪═══════╪══════╪══════╪═══════╪══════╪══════╪════════╪══════╪═════╡
# │  0 │    59 │     2 │  32.1 │  101 │  157 │  93.2 │   38 │    4 │ 4.8598 │   87 │ 151 │
# ├────┼───────┼───────┼───────┼──────┼──────┼───────┼──────┼──────┼────────┼──────┼─────┤
# │  1 │    48 │     1 │  21.6 │   87 │  183 │ 103.2 │   70 │    3 │ 3.8918 │   69 │  75 │
# ├────┼───────┼───────┼───────┼──────┼──────┼───────┼──────┼──────┼────────┼──────┼─────┤
# │  2 │    72 │     2 │  30.5 │   93 │  156 │  93.6 │   41 │    4 │ 4.6728 │   85 │ 141 │
# ├────┼───────┼───────┼───────┼──────┼──────┼───────┼──────┼──────┼────────┼──────┼─────┤
# │  3 │    24 │     1 │  25.3 │   84 │  198 │ 131.4 │   40 │    5 │ 4.8903 │   89 │ 206 │
# ├────┼───────┼───────┼───────┼──────┼──────┼───────┼──────┼──────┼────────┼──────┼─────┤
# │  4 │    50 │     1 │  23   │  101 │  192 │ 125.4 │   52 │    4 │ 4.2905 │   80 │ 135 │
# ╘════╧═══════╧═══════╧═══════╧══════╧══════╧═══════╧══════╧══════╧════════╧══════╧═════╛
#
# DataFrame 4:
# ╒════╤═══════════════╤═══════════╤═════════════════╤═════════════════╤═══════════╤═══════╤════════════════════════════╤═══════╤═══════════╕
# │    │   Pregnancies │   Glucose │   Bloodpressure │   Skinthickness │   Insulin │   Bmi │   Diabetespedigreefunction │   Age │   Outcome │
# ╞════╪═══════════════╪═══════════╪═════════════════╪═════════════════╪═══════════╪═══════╪════════════════════════════╪═══════╪═══════════╡
# │  0 │             6 │       148 │              72 │              35 │         0 │  33.6 │                      0.627 │    50 │         1 │
# ├────┼───────────────┼───────────┼─────────────────┼─────────────────┼───────────┼───────┼────────────────────────────┼───────┼───────────┤
# │  1 │             1 │        85 │              66 │              29 │         0 │  26.6 │                      0.351 │    31 │         0 │
# ├────┼───────────────┼───────────┼─────────────────┼─────────────────┼───────────┼───────┼────────────────────────────┼───────┼───────────┤
# │  2 │             8 │       183 │              64 │               0 │         0 │  23.3 │                      0.672 │    32 │         1 │
# ├────┼───────────────┼───────────┼─────────────────┼─────────────────┼───────────┼───────┼────────────────────────────┼───────┼───────────┤
# │  3 │             1 │        89 │              66 │              23 │        94 │  28.1 │                      0.167 │    21 │         0 │
# ├────┼───────────────┼───────────┼─────────────────┼─────────────────┼───────────┼───────┼────────────────────────────┼───────┼───────────┤
# │  4 │             0 │       137 │              40 │              35 │       168 │  43.1 │                      2.288 │    33 │         1 │
# ╘════╧═══════════════╧═══════════╧═════════════════╧═════════════════╧═══════════╧═══════╧════════════════════════════╧═══════╧═══════════╛

# %%
# Renaming columns
txt.rename(columns={'S6': 'Glucose'}, inplace=True)
csv.rename(columns={'age': 'Age'}, inplace=True)
csv.rename(columns={'bmi': 'bmi_x'}, inplace=True)
csv.rename(columns={'blood_glucose_level': 'Glucose'}, inplace=True)
csv.rename(columns={'diabetes': 'Outcome'}, inplace=True)
csv.rename(columns={'gender': 'Sex'}, inplace=True)
xlsx.rename(columns={'Bmi': 'bmi_y'}, inplace=True)
csv.rename(columns={'Glucose': 'glucose'}, inplace=True)

# %%
print_dataframes(csv, xlsx, txt, csv0)
# Out:
# DataFrame 1:
# ╒════╤════════╤═══════╤════════════════╤═════════════════╤═══════════════════╤═════════╤═══════════════╤═══════════╤═══════════╕
# │    │ Sex    │   Age │   hypertension │   heart_disease │ smoking_history   │   bmi_x │   Hba1c_level │   glucose │   Outcome │
# ╞════╪════════╪═══════╪════════════════╪═════════════════╪═══════════════════╪═════════╪═══════════════╪═══════════╪═══════════╡
# │  0 │ Female │    80 │              0 │               1 │ never             │   25.19 │           6.6 │       140 │         0 │
# ├────┼────────┼───────┼────────────────┼─────────────────┼───────────────────┼─────────┼───────────────┼───────────┼───────────┤
# │  1 │ Female │    54 │              0 │               0 │ No Info           │   27.32 │           6.6 │        80 │         0 │
# ├────┼────────┼───────┼────────────────┼─────────────────┼───────────────────┼─────────┼───────────────┼───────────┼───────────┤
# │  2 │ Male   │    28 │              0 │               0 │ never             │   27.32 │           5.7 │       158 │         0 │
# ├────┼────────┼───────┼────────────────┼─────────────────┼───────────────────┼─────────┼───────────────┼───────────┼───────────┤
# │  3 │ Female │    36 │              0 │               0 │ current           │   23.45 │           5   │       155 │         0 │
# ├────┼────────┼───────┼────────────────┼─────────────────┼───────────────────┼─────────┼───────────────┼───────────┼───────────┤
# │  4 │ Male   │    76 │              1 │               1 │ current           │   20.14 │           4.8 │       155 │         0 │
# ╘════╧════════╧═══════╧════════════════╧═════════════════╧═══════════════════╧═════════╧═══════════════╧═══════════╧═══════════╛
#
# DataFrame 2:
# ╒════╤═══════════════╤═══════════╤═════════════════╤═════════════════╤═══════════╤═════════╤════════════════════════════╤═══════╤════════╤═══════════╕
# │    │   Pregnancies │   Glucose │   Bloodpressure │   Skinthickness │   Insulin │   bmi_y │   Diabetespedigreefunction │   Age │   Skin │ Outcome   │
# ╞════╪═══════════════╪═══════════╪═════════════════╪═════════════════╪═══════════╪═════════╪════════════════════════════╪═══════╪════════╪═══════════╡
# │  0 │             6 │       148 │              72 │              35 │         0 │    33.6 │                      0.627 │    50 │ 1.379  │ True      │
# ├────┼───────────────┼───────────┼─────────────────┼─────────────────┼───────────┼─────────┼────────────────────────────┼───────┼────────┼───────────┤
# │  1 │             1 │        85 │              66 │              29 │         0 │    26.6 │                      0.351 │    31 │ 1.1426 │ False     │
# ├────┼───────────────┼───────────┼─────────────────┼─────────────────┼───────────┼─────────┼────────────────────────────┼───────┼────────┼───────────┤
# │  2 │             8 │       183 │              64 │               0 │         0 │    23.3 │                      0.672 │    32 │ 0      │ True      │
# ├────┼───────────────┼───────────┼─────────────────┼─────────────────┼───────────┼─────────┼────────────────────────────┼───────┼────────┼───────────┤
# │  3 │             1 │        89 │              66 │              23 │        94 │    28.1 │                      0.167 │    21 │ 0.9062 │ False     │
# ├────┼───────────────┼───────────┼─────────────────┼─────────────────┼───────────┼─────────┼────────────────────────────┼───────┼────────┼───────────┤
# │  4 │             0 │       137 │              40 │              35 │       168 │    43.1 │                      2.288 │    33 │ 1.379  │ True      │
# ╘════╧═══════════════╧═══════════╧═════════════════╧═════════════════╧═══════════╧═════════╧════════════════════════════╧═══════╧════════╧═══════════╛
#
# DataFrame 3:
# ╒════╤═══════╤═══════╤═══════╤══════╤══════╤═══════╤══════╤══════╤════════╤═══════════╤═════╕
# │    │   Age │   Sex │   Bmi │   Bp │   S1 │    S2 │   S3 │   S4 │     S5 │   Glucose │   Y │
# ╞════╪═══════╪═══════╪═══════╪══════╪══════╪═══════╪══════╪══════╪════════╪═══════════╪═════╡
# │  0 │    59 │     2 │  32.1 │  101 │  157 │  93.2 │   38 │    4 │ 4.8598 │        87 │ 151 │
# ├────┼───────┼───────┼───────┼──────┼──────┼───────┼──────┼──────┼────────┼───────────┼─────┤
# │  1 │    48 │     1 │  21.6 │   87 │  183 │ 103.2 │   70 │    3 │ 3.8918 │        69 │  75 │
# ├────┼───────┼───────┼───────┼──────┼──────┼───────┼──────┼──────┼────────┼───────────┼─────┤
# │  2 │    72 │     2 │  30.5 │   93 │  156 │  93.6 │   41 │    4 │ 4.6728 │        85 │ 141 │
# ├────┼───────┼───────┼───────┼──────┼──────┼───────┼──────┼──────┼────────┼───────────┼─────┤
# │  3 │    24 │     1 │  25.3 │   84 │  198 │ 131.4 │   40 │    5 │ 4.8903 │        89 │ 206 │
# ├────┼───────┼───────┼───────┼──────┼──────┼───────┼──────┼──────┼────────┼───────────┼─────┤
# │  4 │    50 │     1 │  23   │  101 │  192 │ 125.4 │   52 │    4 │ 4.2905 │        80 │ 135 │
# ╘════╧═══════╧═══════╧═══════╧══════╧══════╧═══════╧══════╧══════╧════════╧═══════════╧═════╛
#
# DataFrame 4:
# ╒════╤═══════════════╤═══════════╤═════════════════╤═════════════════╤═══════════╤═══════╤════════════════════════════╤═══════╤═══════════╕
# │    │   Pregnancies │   Glucose │   Bloodpressure │   Skinthickness │   Insulin │   Bmi │   Diabetespedigreefunction │   Age │   Outcome │
# ╞════╪═══════════════╪═══════════╪═════════════════╪═════════════════╪═══════════╪═══════╪════════════════════════════╪═══════╪═══════════╡
# │  0 │             6 │       148 │              72 │              35 │         0 │  33.6 │                      0.627 │    50 │         1 │
# ├────┼───────────────┼───────────┼─────────────────┼─────────────────┼───────────┼───────┼────────────────────────────┼───────┼───────────┤
# │  1 │             1 │        85 │              66 │              29 │         0 │  26.6 │                      0.351 │    31 │         0 │
# ├────┼───────────────┼───────────┼─────────────────┼─────────────────┼───────────┼───────┼────────────────────────────┼───────┼───────────┤
# │  2 │             8 │       183 │              64 │               0 │         0 │  23.3 │                      0.672 │    32 │         1 │
# ├────┼───────────────┼───────────┼─────────────────┼─────────────────┼───────────┼───────┼────────────────────────────┼───────┼───────────┤
# │  3 │             1 │        89 │              66 │              23 │        94 │  28.1 │                      0.167 │    21 │         0 │
# ├────┼───────────────┼───────────┼─────────────────┼─────────────────┼───────────┼───────┼────────────────────────────┼───────┼───────────┤
# │  4 │             0 │       137 │              40 │              35 │       168 │  43.1 │                      2.288 │    33 │         1 │
# ╘════╧═══════════════╧═══════════╧═════════════════╧═════════════════╧═══════════╧═══════╧════════════════════════════╧═══════╧═══════════╛

# %%
txt['Sex'].unique()
# Out:
# array([2, 1])

# %%
csv['Sex'].unique()
# Out:
# array(['Female', 'Male', 'Other'], dtype=object)

# %%
# Mapping values in the 'Sex' column
sex_mapping = {'Female': 0, 'Male': 1, 'Other': 2}
csv['Sex'] = csv['Sex'].map(sex_mapping)

# %%
sex_mapping = {1: 0, 2: 1}
txt['Sex'] = txt['Sex'].map(sex_mapping)

# %%
print_dataframes(csv, xlsx, txt, csv0)
# Out:
# DataFrame 1:
# ╒════╤═══════╤═══════╤════════════════╤═════════════════╤═══════════════════╤═════════╤═══════════════╤═══════════╤═══════════╕
# │    │   Sex │   Age │   hypertension │   heart_disease │ smoking_history   │   bmi_x │   Hba1c_level │   glucose │   Outcome │
# ╞════╪═══════╪═══════╪════════════════╪═════════════════╪═══════════════════╪═════════╪═══════════════╪═══════════╪═══════════╡
# │  0 │     0 │    80 │              0 │               1 │ never             │   25.19 │           6.6 │       140 │         0 │
# ├────┼───────┼───────┼────────────────┼─────────────────┼───────────────────┼─────────┼───────────────┼───────────┼───────────┤
# │  1 │     0 │    54 │              0 │               0 │ No Info           │   27.32 │           6.6 │        80 │         0 │
# ├────┼───────┼───────┼────────────────┼─────────────────┼───────────────────┼─────────┼───────────────┼───────────┼───────────┤
# │  2 │     1 │    28 │              0 │               0 │ never             │   27.32 │           5.7 │       158 │         0 │
# ├────┼───────┼───────┼────────────────┼─────────────────┼───────────────────┼─────────┼───────────────┼───────────┼───────────┤
# │  3 │     0 │    36 │              0 │               0 │ current           │   23.45 │           5   │       155 │         0 │
# ├────┼───────┼───────┼────────────────┼─────────────────┼───────────────────┼─────────┼───────────────┼───────────┼───────────┤
# │  4 │     1 │    76 │              1 │               1 │ current           │   20.14 │           4.8 │       155 │         0 │
# ╘════╧═══════╧═══════╧════════════════╧═════════════════╧═══════════════════╧═════════╧═══════════════╧═══════════╧═══════════╛
#
# DataFrame 2:
# ╒════╤═══════════════╤═══════════╤═════════════════╤═════════════════╤═══════════╤═════════╤════════════════════════════╤═══════╤════════╤═══════════╕
# │    │   Pregnancies │   Glucose │   Bloodpressure │   Skinthickness │   Insulin │   bmi_y │   Diabetespedigreefunction │   Age │   Skin │ Outcome   │
# ╞════╪═══════════════╪═══════════╪═════════════════╪═════════════════╪═══════════╪═════════╪════════════════════════════╪═══════╪════════╪═══════════╡
# │  0 │             6 │       148 │              72 │              35 │         0 │    33.6 │                      0.627 │    50 │ 1.379  │ True      │
# ├────┼───────────────┼───────────┼─────────────────┼─────────────────┼───────────┼─────────┼────────────────────────────┼───────┼────────┼───────────┤
# │  1 │             1 │        85 │              66 │              29 │         0 │    26.6 │                      0.351 │    31 │ 1.1426 │ False     │
# ├────┼───────────────┼───────────┼─────────────────┼─────────────────┼───────────┼─────────┼────────────────────────────┼───────┼────────┼───────────┤
# │  2 │             8 │       183 │              64 │               0 │         0 │    23.3 │                      0.672 │    32 │ 0      │ True      │
# ├────┼───────────────┼───────────┼─────────────────┼─────────────────┼───────────┼─────────┼────────────────────────────┼───────┼────────┼───────────┤
# │  3 │             1 │        89 │              66 │              23 │        94 │    28.1 │                      0.167 │    21 │ 0.9062 │ False     │
# ├────┼───────────────┼───────────┼─────────────────┼─────────────────┼───────────┼─────────┼────────────────────────────┼───────┼────────┼───────────┤
# │  4 │             0 │       137 │              40 │              35 │       168 │    43.1 │                      2.288 │    33 │ 1.379  │ True      │
# ╘════╧═══════════════╧═══════════╧═════════════════╧═════════════════╧═══════════╧═════════╧════════════════════════════╧═══════╧════════╧═══════════╛
#
# DataFrame 3:
# ╒════╤═══════╤═══════╤═══════╤══════╤══════╤═══════╤══════╤══════╤════════╤═══════════╤═════╕
# │    │   Age │   Sex │   Bmi │   Bp │   S1 │    S2 │   S3 │   S4 │     S5 │   Glucose │   Y │
# ╞════╪═══════╪═══════╪═══════╪══════╪══════╪═══════╪══════╪══════╪════════╪═══════════╪═════╡
# │  0 │    59 │     1 │  32.1 │  101 │  157 │  93.2 │   38 │    4 │ 4.8598 │        87 │ 151 │
# ├────┼───────┼───────┼───────┼──────┼──────┼───────┼──────┼──────┼────────┼───────────┼─────┤
# │  1 │    48 │     0 │  21.6 │   87 │  183 │ 103.2 │   70 │    3 │ 3.8918 │        69 │  75 │
# ├────┼───────┼───────┼───────┼──────┼──────┼───────┼──────┼──────┼────────┼───────────┼─────┤
# │  2 │    72 │     1 │  30.5 │   93 │  156 │  93.6 │   41 │    4 │ 4.6728 │        85 │ 141 │
# ├────┼───────┼───────┼───────┼──────┼──────┼───────┼──────┼──────┼────────┼───────────┼─────┤
# │  3 │    24 │     0 │  25.3 │   84 │  198 │ 131.4 │   40 │    5 │ 4.8903 │        89 │ 206 │
# ├────┼───────┼───────┼───────┼──────┼──────┼───────┼──────┼──────┼────────┼───────────┼─────┤
# │  4 │    50 │     0 │  23   │  101 │  192 │ 125.4 │   52 │    4 │ 4.2905 │        80 │ 135 │
# ╘════╧═══════╧═══════╧═══════╧══════╧══════╧═══════╧══════╧══════╧════════╧═══════════╧═════╛
#
# DataFrame 4:
# ╒════╤═══════════════╤═══════════╤═════════════════╤═════════════════╤═══════════╤═══════╤════════════════════════════╤═══════╤═══════════╕
# │    │   Pregnancies │   Glucose │   Bloodpressure │   Skinthickness │   Insulin │   Bmi │   Diabetespedigreefunction │   Age │   Outcome │
# ╞════╪═══════════════╪═══════════╪═════════════════╪═════════════════╪═══════════╪═══════╪════════════════════════════╪═══════╪═══════════╡
# │  0 │             6 │       148 │              72 │              35 │         0 │  33.6 │                      0.627 │    50 │         1 │
# ├────┼───────────────┼───────────┼─────────────────┼─────────────────┼───────────┼───────┼────────────────────────────┼───────┼───────────┤
# │  1 │             1 │        85 │              66 │              29 │         0 │  26.6 │                      0.351 │    31 │         0 │
# ├────┼───────────────┼───────────┼─────────────────┼─────────────────┼───────────┼───────┼────────────────────────────┼───────┼───────────┤
# │  2 │             8 │       183 │              64 │               0 │         0 │  23.3 │                      0.672 │    32 │         1 │
# ├────┼───────────────┼───────────┼─────────────────┼─────────────────┼───────────┼───────┼────────────────────────────┼───────┼───────────┤
# │  3 │             1 │        89 │              66 │              23 │        94 │  28.1 │                      0.167 │    21 │         0 │
# ├────┼───────────────┼───────────┼─────────────────┼─────────────────┼───────────┼───────┼────────────────────────────┼───────┼───────────┤
# │  4 │             0 │       137 │              40 │              35 │       168 │  43.1 │                      2.288 │    33 │         1 │
# ╘════╧═══════════════╧═══════════╧═════════════════╧═════════════════╧═══════════╧═══════╧════════════════════════════╧═══════╧═══════════╛

# %%
txt_c = txt.columns.tolist()
csv_c = csv.columns.tolist()
xlsx_c = xlsx.columns.tolist()
csv0_c = csv0.columns.tolist()

# %%
# Common columns
commons = set(txt_c) & set(xlsx_c)
commons = list(commons)
commons
# Out:
# ['Age', 'Glucose']

# %%
# Check data types for the specified columns
txt[commons].dtypes
# Out:
# Age        int64
# Glucose    int64
# dtype: object

# %%
xlsx[commons].dtypes
# Out:
# Age        int64
# Glucose    int64
# dtype: object

# %%
# Merging txt and xlsx DataFrames on common columns using inner join
df1 = pd.merge(txt, xlsx, on=commons, how='inner')

# %%
df1.shape
# Out:
# (44, 19)

# %%
df1_c = df1.columns.tolist()

# %%
commons1 = set(df1_c) & set(csv_c)
commons1 = list(commons1)
commons1
# Out:
# ['Outcome', 'Age', 'Sex']

# %%
df1[commons1].dtypes
# Out:
# Outcome     bool
# Age        int64
# Sex        int64
# dtype: object

# %%
csv[commons1].dtypes
# Out:
# Outcome      int64
# Age        float64
# Sex          int64
# dtype: object

# %%
csv['Age'] = csv['Age'].astype(int)

# %%
# Merging df1 and csv DataFrames on common columns using inner join
df2 = pd.merge(df1, csv, on=commons1, how='inner')
df2.head()
# Out:
#    Age  Sex   Bmi    Bp   S1    S2    S3   S4      S5  Glucose  ...  bmi_y  \
# 0   23    0  22.6  89.0  139  64.8  61.0  2.0  4.1897       68  ...   20.1
# 1   23    0  22.6  89.0  139  64.8  61.0  2.0  4.1897       68  ...   20.1
# 2   23    0  22.6  89.0  139  64.8  61.0  2.0  4.1897       68  ...   20.1
# 3   23    0  22.6  89.0  139  64.8  61.0  2.0  4.1897       68  ...   20.1
# 4   23    0  22.6  89.0  139  64.8  61.0  2.0  4.1897       68  ...   20.1
#
#    Diabetespedigreefunction    Skin  Outcome  hypertension  heart_disease  \
# 0                     0.257  0.5122    False             0              0
# 1                     0.257  0.5122    False             0              0
# 2                     0.257  0.5122    False             0              0
# 3                     0.257  0.5122    False             0              0
# 4                     0.257  0.5122    False             0              0
#
#    smoking_history  bmi_x Hba1c_level  glucose
# 0          No Info  24.56         3.5      155
# 1            never  24.21         3.5      140
# 2            never  22.55         4.0      158
# 3            never  27.32         6.0      140
# 4          current  24.37         6.0      140
#
# [5 rows x 25 columns]

# %%
df2.shape
# Out:
# (26880, 25)

# %%
df2.duplicated().any()
# Out:
# False

# %%
df2.columns
# Out:
# Index(['Age', 'Sex', 'Bmi', 'Bp', 'S1', 'S2', 'S3', 'S4', 'S5', 'Glucose', 'Y',
#        'Pregnancies', 'Bloodpressure', 'Skinthickness', 'Insulin', 'bmi_y',
#        'Diabetespedigreefunction', 'Skin', 'Outcome', 'hypertension',
#        'heart_disease', 'smoking_history', 'bmi_x', 'Hba1c_level', 'glucose'],
#       dtype='object')

# %%
df2_c = df2.columns.tolist()
commons = set(df2_c) & set(csv0_c)
commons = list(commons)
commons
# Out:
# ['Age',
#  'Bloodpressure',
#  'Outcome',
#  'Diabetespedigreefunction',
#  'Pregnancies',
#  'Insulin',
#  'Skinthickness',
#  'Bmi',
#  'Glucose']

# %%
# Merging txt and xlsx DataFrames on common columns using inner join
df2 = pd.merge(df2, csv0, on=commons, how='left')

# %% [markdown]
# # Data Visualization

# %%
df2.head()
# Out:
#    Age  Sex   Bmi    Bp   S1    S2    S3   S4      S5  Glucose  ...  bmi_y  \
# 0   23    0  22.6  89.0  139  64.8  61.0  2.0  4.1897       68  ...   20.1
# 1   23    0  22.6  89.0  139  64.8  61.0  2.0  4.1897       68  ...   20.1
# 2   23    0  22.6  89.0  139  64.8  61.0  2.0  4.1897       68  ...   20.1
# 3   23    0  22.6  89.0  139  64.8  61.0  2.0  4.1897       68  ...   20.1
# 4   23    0  22.6  89.0  139  64.8  61.0  2.0  4.1897       68  ...   20.1
#
#    Diabetespedigreefunction    Skin  Outcome  hypertension  heart_disease  \
# 0                     0.257  0.5122    False             0              0
# 1                     0.257  0.5122    False             0              0
# 2                     0.257  0.5122    False             0              0
# 3                     0.257  0.5122    False             0              0
# 4                     0.257  0.5122    False             0              0
#
#    smoking_history  bmi_x Hba1c_level  glucose
# 0          No Info  24.56         3.5      155
# 1            never  24.21         3.5      140
# 2            never  22.55         4.0      158
# 3            never  27.32         6.0      140
# 4          current  24.37         6.0      140
#
# [5 rows x 25 columns]

# %%
# Creating a histogram of the 'Age' column using Seaborn displot
fx = sns.displot(data= df2, x='Age', kind='hist', color = sns.color_palette()[1], bins = 20)
# Setting title, xlabel, and ylabel for better clarity
fx.set(title='Age Histogram', xlabel='Age', ylabel='Frequency')

# %%
fx = sns.violinplot(df2, y='Age', inner='box')
fx.set(title='Age Violin Plot')
# Out:
# [Text(0.5, 1.0, 'Age Violin Plot')]

# %%
# Box plot
sns.boxplot(x='Outcome', y='Insulin', data=df2)

# Set labels and title
plt.xlabel('Diabetes Outcome')
plt.ylabel('Insulin')
plt.title('Insulin Levels by Diabetes Outcome')

# Show the plot
plt.show()

# %% [markdown]
# The distribution is skewed to the left (younger ages), meaning that there are more people diagnosed with diabetes at younger ages than at older ages. This may be because of the following factors:
#
# - **Type 1 diabetes:** Type 1 diabetes is an autoimmune disease that typically develops in childhood or adolescence. It is caused by the body's immune system attacking the cells in the pancreas that produce insulin.
# - **Childhood obesity:** Childhood obesity is a major risk factor for developing type 2 diabetes. Obese children are more likely to develop insulin resistance, which can lead to type 2 diabetes.
# - **Gestational diabetes:** Gestational diabetes is a type of diabetes that can develop during pregnancy. It usually goes away after childbirth, but women who have had gestational diabetes are at an increased risk of developing type 2 diabetes later in life.

# %%
# Create a KDE plot for the 'Bmi' variable
fx = sns.displot(data=df2, x='Bmi', kind='kde', fill=True)

# Set the title and axis labels
fx.fig.suptitle('BMI KDE Plot', y=1.02)
fx.set(xlabel='BMI', ylabel='Density')

# Show the plot
plt.show()

# %%
# Creating a box plot of the 'Bmi' column using Seaborn catplot
fx= sns.catplot(data= df2, y='Bmi', color=sns.color_palette()[9], kind='box')
# Setting title for better clarity
fx.set(title='BMI Box Plot')

# %%
# Counting the occurrences of each unique value in the 'Bmi' column
df2['Bmi'].value_counts()
# Out:
# Bmi
# 24.2    2406
# 22.6    1575
# 19.3    1560
# 23.0    1560
# 20.1    1514
# 20.3    1494
# 24.9    1246
# 30.6    1240
# 29.5     846
# 30.0     839
# 21.0     839
# 30.4     831
# 22.9     806
# 20.9     797
# 24.3     788
# 29.0     787
# 28.3     787
# 18.6     780
# 20.2     750
# 28.2     749
# 28.7     721
# 23.5     703
# 32.4     687
# 27.0     675
# 21.2     524
# 27.7     468
# 24.1     422
# 27.5     309
# 31.0     102
# 38.2      42
# 32.3      19
# 35.3      14
# Name: count, dtype: int64

# %%
# Sampling 50 random rows from the DataFrame where 'Bmi' is equal to 24.2
df2.query('Bmi == 24.2').sample(50)
# Out:
#        Age  Sex   Bmi    Bp   S1     S2    S3   S4      S5  Glucose  ...  \
# 23029   28    0  24.2  93.0  174  106.4  54.0  3.0  4.2195       84  ...
# 22702   28    0  24.2  93.0  174  106.4  54.0  3.0  4.2195       84  ...
# 22168   28    0  24.2  93.0  174  106.4  54.0  3.0  4.2195       84  ...
# 22885   28    0  24.2  93.0  174  106.4  54.0  3.0  4.2195       84  ...
# 22388   28    0  24.2  93.0  174  106.4  54.0  3.0  4.2195       84  ...
# 6347    54    0  24.2  74.0  204  109.0  82.0  2.0  4.1744      109  ...
# 22265   28    0  24.2  93.0  174  106.4  54.0  3.0  4.2195       84  ...
# 21971   28    0  24.2  93.0  174  106.4  54.0  3.0  4.2195       84  ...
# 6477    54    0  24.2  74.0  204  109.0  82.0  2.0  4.1744      109  ...
# 22955   28    0  24.2  93.0  174  106.4  54.0  3.0  4.2195       84  ...
# 23461   28    0  24.2  93.0  174  106.4  54.0  3.0  4.2195       84  ...
# 23577   28    0  24.2  93.0  174  106.4  54.0  3.0  4.2195       84  ...
# 6149    54    0  24.2  74.0  204  109.0  82.0  2.0  4.1744      109  ...
# 22040   28    0  24.2  93.0  174  106.4  54.0  3.0  4.2195       84  ...
# 6123    54    0  24.2  74.0  204  109.0  82.0  2.0  4.1744      109  ...
# 6461    54    0  24.2  74.0  204  109.0  82.0  2.0  4.1744      109  ...
# 23468   28    0  24.2  93.0  174  106.4  54.0  3.0  4.2195       84  ...
# 22899   28    0  24.2  93.0  174  106.4  54.0  3.0  4.2195       84  ...
# 6101    54    0  24.2  74.0  204  109.0  82.0  2.0  4.1744      109  ...
# 23168   28    0  24.2  93.0  174  106.4  54.0  3.0  4.2195       84  ...
# 6355    54    0  24.2  74.0  204  109.0  82.0  2.0  4.1744      109  ...
# 23025   28    0  24.2  93.0  174  106.4  54.0  3.0  4.2195       84  ...
# 22819   28    0  24.2  93.0  174  106.4  54.0  3.0  4.2195       84  ...
# 23370   28    0  24.2  93.0  174  106.4  54.0  3.0  4.2195       84  ...
# 22171   28    0  24.2  93.0  174  106.4  54.0  3.0  4.2195       84  ...
# 22808   28    0  24.2  93.0  174  106.4  54.0  3.0  4.2195       84  ...
# 6226    54    0  24.2  74.0  204  109.0  82.0  2.0  4.1744      109  ...
# 5839    54    0  24.2  74.0  204  109.0  82.0  2.0  4.1744      109  ...
# 23262   28    0  24.2  93.0  174  106.4  54.0  3.0  4.2195       84  ...
# 6425    54    0  24.2  74.0  204  109.0  82.0  2.0  4.1744      109  ...
# 5804    54    0  24.2  74.0  204  109.0  82.0  2.0  4.1744      109  ...
# 23069   28    0  24.2  93.0  174  106.4  54.0  3.0  4.2195       84  ...
# 5964    54    0  24.2  74.0  204  109.0  82.0  2.0  4.1744      109  ...
# 23412   28    0  24.2  93.0  174  106.4  54.0  3.0  4.2195       84  ...
# 22210   28    0  24.2  93.0  174  106.4  54.0  3.0  4.2195       84  ...
# 6371    54    0  24.2  74.0  204  109.0  82.0  2.0  4.1744      109  ...
# 22834   28    0  24.2  93.0  174  106.4  54.0  3.0  4.2195       84  ...
# 5835    54    0  24.2  74.0  204  109.0  82.0  2.0  4.1744      109  ...
# 23351   28    0  24.2  93.0  174  106.4  54.0  3.0  4.2195       84  ...
# 22745   28    0  24.2  93.0  174  106.4  54.0  3.0  4.2195       84  ...
# 23521   28    0  24.2  93.0  174  106.4  54.0  3.0  4.2195       84  ...
# 6056    54    0  24.2  74.0  204  109.0  82.0  2.0  4.1744      109  ...
# 6180    54    0  24.2  74.0  204  109.0  82.0  2.0  4.1744      109  ...
# 6292    54    0  24.2  74.0  204  109.0  82.0  2.0  4.1744      109  ...
# 23204   28    0  24.2  93.0  174  106.4  54.0  3.0  4.2195       84  ...
# 22346   28    0  24.2  93.0  174  106.4  54.0  3.0  4.2195       84  ...
# 22836   28    0  24.2  93.0  174  106.4  54.0  3.0  4.2195       84  ...
# 22570   28    0  24.2  93.0  174  106.4  54.0  3.0  4.2195       84  ...
# 22481   28    0  24.2  93.0  174  106.4  54.0  3.0  4.2195       84  ...
# 22525   28    0  24.2  93.0  174  106.4  54.0  3.0  4.2195       84  ...
#
#        bmi_y  Diabetespedigreefunction    Skin  Outcome  hypertension  \
# 23029   36.9                     0.471  0.9062    False             0
# 22702   37.2                     0.267  1.2608    False             0
# 22168   37.2                     0.267  1.2608    False             0
# 22885   36.9                     0.471  0.9062    False             0
# 22388   37.2                     0.267  1.2608    False             0
# 6347    42.7                     0.845  0.0000    False             0
# 22265   37.2                     0.267  1.2608    False             0
# 21971   37.2                     0.267  1.2608    False             0
# 6477    42.7                     0.845  0.0000    False             0
# 22955   36.9                     0.471  0.9062    False             0
# 23461   36.9                     0.471  0.9062    False             0
# 23577   36.9                     0.471  0.9062    False             0
# 6149    42.7                     0.845  0.0000    False             0
# 22040   37.2                     0.267  1.2608    False             0
# 6123    42.7                     0.845  0.0000    False             0
# 6461    42.7                     0.845  0.0000    False             1
# 23468   36.9                     0.471  0.9062    False             0
# 22899   36.9                     0.471  0.9062    False             0
# 6101    42.7                     0.845  0.0000    False             0
# 23168   36.9                     0.471  0.9062    False             0
# 6355    42.7                     0.845  0.0000    False             0
# 23025   36.9                     0.471  0.9062    False             0
# 22819   36.9                     0.471  0.9062    False             0
# 23370   36.9                     0.471  0.9062    False             0
# 22171   37.2                     0.267  1.2608    False             0
# 22808   36.9                     0.471  0.9062    False             0
# 6226    42.7                     0.845  0.0000    False             0
# 5839    42.7                     0.845  0.0000    False             0
# 23262   36.9                     0.471  0.9062    False             0
# 6425    42.7                     0.845  0.0000    False             0
# 5804    42.7                     0.845  0.0000    False             0
# 23069   36.9                     0.471  0.9062    False             0
# 5964    42.7                     0.845  0.0000    False             0
# 23412   36.9                     0.471  0.9062    False             0
# 22210   37.2                     0.267  1.2608    False             0
# 6371    42.7                     0.845  0.0000    False             0
# 22834   36.9                     0.471  0.9062    False             0
# 5835    42.7                     0.845  0.0000    False             0
# 23351   36.9                     0.471  0.9062    False             0
# 22745   37.2                     0.267  1.2608    False             0
# 23521   36.9                     0.471  0.9062    False             0
# 6056    42.7                     0.845  0.0000    False             0
# 6180    42.7                     0.845  0.0000    False             0
# 6292    42.7                     0.845  0.0000    False             0
# 23204   36.9                     0.471  0.9062    False             0
# 22346   37.2                     0.267  1.2608    False             0
# 22836   36.9                     0.471  0.9062    False             0
# 22570   37.2                     0.267  1.2608    False             0
# 22481   37.2                     0.267  1.2608    False             0
# 22525   37.2                     0.267  1.2608    False             0
#
#        heart_disease  smoking_history  bmi_x Hba1c_level  glucose
# 23029              0      not current  34.97         6.5      140
# 22702              0           former  40.20         4.5      160
# 22168              0          No Info  19.25         4.5      126
# 22885              0          No Info  27.32         5.7      200
# 22388              0          current  23.43         6.1      126
# 6347               0            never  25.11         5.7      140
# 22265              0            never  25.08         3.5       80
# 21971              0             ever  33.37         6.2      155
# 6477               0            never  31.98         5.7       90
# 22955              0             ever  23.18         5.8      158
# 23461              0            never  23.13         6.6      160
# 23577              0          No Info  25.62         6.2      158
# 6149               0           former  22.70         4.5      155
# 22040              0          No Info  22.49         6.0       80
# 6123               0            never  27.32         6.5      100
# 6461               0          No Info  27.32         6.0      159
# 23468              0          current  34.61         5.0      160
# 22899              0           former  25.54         4.5      159
# 6101               1             ever  29.99         6.2       85
# 23168              0            never  39.12         5.7      159
# 6355               0            never  25.87         6.5       80
# 23025              0          current  28.57         5.8       90
# 22819              0           former  27.32         6.2       80
# 23370              0            never  27.32         6.0      126
# 22171              0          No Info  27.32         6.2      159
# 22808              0            never  25.04         5.7      126
# 6226               0            never  29.24         6.0      155
# 5839               0            never  21.64         4.8       80
# 23262              0          current  23.77         5.0       90
# 6425               0           former  18.68         5.8      140
# 5804               0            never  40.10         6.5      155
# 23069              0      not current  25.67         3.5      145
# 5964               0            never  23.72         6.5      160
# 23412              0            never  42.75         4.8       80
# 22210              0            never  24.19         5.7       90
# 6371               0            never  26.95         4.8      200
# 22834              0            never  22.11         6.0      145
# 5835               0            never  21.13         5.7      100
# 23351              0      not current  27.51         6.6      145
# 22745              0          No Info  20.52         5.8       80
# 23521              0           former  28.46         6.5      200
# 6056               0      not current  30.30         6.0      158
# 6180               0          current  29.89         6.0      158
# 6292               0          No Info  33.56         4.5       80
# 23204              0            never  27.25         6.6      140
# 22346              0          No Info  28.81         6.1      160
# 22836              0          No Info  26.60         4.0      160
# 22570              0            never  28.48         5.7       85
# 22481              0      not current  26.58         5.7      126
# 22525              0          No Info  26.77         5.8      155
#
# [50 rows x 25 columns]

# %%
# Filtering rows where 'Age' is less than 29 and 'Bmi' is equal to 24.2
df2.query('Age < 29 and Bmi == 24.2')
# Out:
#        Age  Sex   Bmi    Bp   S1     S2    S3   S4      S5  Glucose  ...  \
# 21963   28    0  24.2  93.0  174  106.4  54.0  3.0  4.2195       84  ...
# 21964   28    0  24.2  93.0  174  106.4  54.0  3.0  4.2195       84  ...
# 21965   28    0  24.2  93.0  174  106.4  54.0  3.0  4.2195       84  ...
# 21966   28    0  24.2  93.0  174  106.4  54.0  3.0  4.2195       84  ...
# 21967   28    0  24.2  93.0  174  106.4  54.0  3.0  4.2195       84  ...
# ...    ...  ...   ...   ...  ...    ...   ...  ...     ...      ...  ...
# 23620   28    0  24.2  93.0  174  106.4  54.0  3.0  4.2195       84  ...
# 23621   28    0  24.2  93.0  174  106.4  54.0  3.0  4.2195       84  ...
# 23622   28    0  24.2  93.0  174  106.4  54.0  3.0  4.2195       84  ...
# 23623   28    0  24.2  93.0  174  106.4  54.0  3.0  4.2195       84  ...
# 23624   28    0  24.2  93.0  174  106.4  54.0  3.0  4.2195       84  ...
#
#        bmi_y  Diabetespedigreefunction    Skin  Outcome  hypertension  \
# 21963   37.2                     0.267  1.2608    False             0
# 21964   37.2                     0.267  1.2608    False             0
# 21965   37.2                     0.267  1.2608    False             0
# 21966   37.2                     0.267  1.2608    False             0
# 21967   37.2                     0.267  1.2608    False             0
# ...      ...                       ...     ...      ...           ...
# 23620   36.9                     0.471  0.9062    False             0
# 23621   36.9                     0.471  0.9062    False             0
# 23622   36.9                     0.471  0.9062    False             0
# 23623   36.9                     0.471  0.9062    False             0
# 23624   36.9                     0.471  0.9062    False             0
#
#        heart_disease  smoking_history  bmi_x Hba1c_level  glucose
# 21963              0      not current  26.79         5.8      200
# 21964              0            never  20.95         6.2       80
# 21965              0          No Info  27.32         6.2      100
# 21966              0            never  26.17         6.6      145
# 21967              0          No Info  27.32         6.2      126
# ...              ...              ...    ...         ...      ...
# 23620              0            never  26.21         6.6      200
# 23621              0            never  27.32         4.0      155
# 23622              0          current  21.95         6.5      158
# 23623              0            never  20.77         6.2      155
# 23624              0            never  24.36         5.8      159
#
# [1662 rows x 25 columns]

# %% [markdown]
# After conducting a thorough analysis of the 'BMI' and 'Age' columns, several key observations and conclusions can be drawn. Firstly, it's noteworthy that no missing values were identified in either of the columns, indicating a completeness of data in these aspects.
#
# Upon investigating the distribution of values, it was observed that there are no significant outliers in either 'BMI' or 'Age,' suggesting a relatively homogeneous dataset. This is important as outliers can sometimes distort the analysis, and their absence contributes to the reliability of the findings.
#
# The distribution of 'BMI' revealed a slight left skewness, indicating that a larger proportion of individuals tend to have slightly lower BMI values. However, it's crucial to note that this skewness is not extreme, suggesting a relatively balanced distribution.
#
# A notable concentration of individuals with a 'BMI' of approximately 24.2 was observed. This could indicate a common value or a specific range that is more prevalent in the dataset. Further exploration may be needed to understand the significance of this particular value.
#
# Upon delving into the relationship between 'BMI' and 'Age,' a pattern emerged where many individuals with a 'BMI' of 24.2 were younger than 29. This correlation may imply that this specific 'BMI' range is more common among younger age groups.
#
# Lastly, it's worth mentioning that the analysis hints at a concentration of individuals within the normal BMI range, typically defined between 24 to 29. This observation aligns with standard health guidelines, further emphasizing the importance of maintaining a healthy BMI for overall well-being.

# %%
# Creating a KDE (Kernel Density Estimate) plot and rug plot for the 'Hba1c_level' column using Seaborn displot
fx = sns.displot(data= df2, x='Hba1c_level', color = sns.color_palette()[9], kind='kde', fill=True)
# Adding a rug plot for data point visualization
sns.rugplot(data= df2, x='Hba1c_level', color = sns.color_palette()[1])
# Setting title for better clarity
fx.set(title='hbA1c Level KDE Plot + Rug Plot')

# %%
# Calculating the percentage distribution of each unique value in the 'Hba1c_level' column
df2['Hba1c_level'].value_counts(normalize=True)*100
# Out:
# Hba1c_level
# 4.5    8.653274
# 5.7    8.560268
# 3.5    8.526786
# 5.0    8.511905
# 6.0    8.500744
# 6.6    8.303571
# 6.5    8.251488
# 4.8    8.244048
# 5.8    8.162202
# 4.0    8.151042
# 6.2    8.039435
# 6.1    7.749256
# 6.8    0.089286
# 9.0    0.074405
# 8.2    0.066964
# 7.5    0.048363
# 8.8    0.037202
# 7.0    0.029762
# Name: proportion, dtype: float64

# %%
# Creating a box plot for the 'Hba1c_level' column using Seaborn catplot
sns.catplot(kind='box', data= df2, y='Hba1c_level')

# %% [markdown]
# The 'Hba1c_level' values are categorical or discrete rather than continuous.
#
# The box plot reveals the existence of some outliers in the distribution of 'Hba1c_level.'
#
# The rug plot is a simple way to visualize the distribution of the data points. It is simply a scatter plot with the x-axis suppressed. The rug plot shows the relative frequency of each data point.
#
# The KDE plot shows that the distribution of HbA1c levels is skewed to the right, with a peak at around 5.6 and 6.5. This means that there are more people with HbA1c levels above 5.5 than there are people with HbA1c levels below 5.5.
#
# The rug plot shows that the vast majority of people in the data set have HbA1c levels between 5 and 6.6. This is considered to be the healthy range for HbA1c levels.
#
# Overall, the rug plot and KDE plot indicate that the data set's distribution of HbA1c levels is generally in good health. Nonetheless, a subset of individuals with HbA1c values less than 5 are classified as pre-diabetic or diabetic.

# %%
# Creating a KDE (Kernel Density Estimate) plot for the 'Age' column with hue based on 'Outcome' using Seaborn displot
sns.displot(kind='kde', data= df2, x='Age', hue= 'Outcome', fill=True)

# %%
# Creating a box plot for the 'Age' column with hue based on 'Outcome'
fx = sns.catplot(kind='box', data= df2, x= 'Outcome', y='Age',hue= 'Outcome')
# Setting custom x-axis tick labels for better clarity
fx.set_xticklabels(['No Diabetes', 'Diabetes'])

# %% [markdown]
# The graph shows that the prevalence of diabetes increases with age. This is because the risk factors for developing diabetes, such as obesity and insulin resistance, are more common in older adults.
#
# The graph also shows that the prevalence of diabetes peaks at around age 60 and then declines slightly. This is likely due to a combination of factors, such as older adults being more likely to have access to healthcare and being more likely to manage their diabetes effectively.

# %%
df2['Sex'].unique()
# Out:
# array([0, 1])

# %%
# Creating a cross-tabulation (contingency table) of 'Sex' and 'Outcome' columns
temp_df = pd.crosstab(df2['Sex'], df2['Outcome'], normalize='columns')*100

# %%
# Creating a heatmap for the cross-tabulation
sns.heatmap(temp_df, annot=True, cmap='summer')
# Out:
# <Axes: xlabel='Outcome', ylabel='Sex'>

# %%
len(df2[df2['Sex'] == 0])
# Out:
# 21805

# %%
len(df2[df2['Sex'] == 1])
# Out:
# 5075

# %%
(21805 - 5075)/len(df2)*100
# Out:
# 62.239583333333336

# %% [markdown]
# - Diabetes affects both genders equally
# - The heatmap shows that the prevalence of diabetes is slightly higher in women than in men. However, it is important to note that the dataset is biased towards women, with 62% more female data than male data. This means that the heatmap is not a completely accurate representation of the distribution of diabetes by gender in the general population.

# %%
# Creating a bar plot for the 'Bmi' column with x-axis based on 'Outcome'
fx = sns.barplot(data= df2, x='Outcome', y='Bmi')
# Setting custom x-axis tick labels for better clarity
fx.set(title='Diabetes vs BMI')
# Setting title for the plot
fx.set_xticklabels(['No Diabetes', 'Diabetes'])
# Out:
# <ipython-input-252-9cb78ae20dba>:6: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   fx.set_xticklabels(['No Diabetes', 'Diabetes'])
# [Text(0, 0, 'No Diabetes'), Text(1, 0, 'Diabetes')]

# %%
# Creating a box plot for the 'Bmi' column with x-axis based on 'Outcome'
fx = sns.catplot(data= df2, x='Outcome', y='Bmi', kind='box')
# Setting custom x-axis tick labels for better clarity
fx.set(title='Diabetes vs BMI')
# Setting title for the plot
fx.set_xticklabels(['No Diabetes', 'Diabetes'])

# %% [markdown]
# The boxplot shows that the median BMI is higher in people with diabetes than in people without diabetes. This means that people with diabetes are more likely to be overweight or obese than people without diabetes.
#
# There are a few possible explanations for this relationship. One possibility is that people with diabetes are more likely to gain weight because of their insulin resistance. Insulin resistance is a condition in which the body's cells do not respond properly to insulin. This can lead to high blood sugar levels and weight gain.
#
# Another possibility is that people with diabetes are more likely to be overweight or obese because of their lifestyle choices. For example, people with diabetes may be more likely to eat unhealthy foods or to be less active physically.

# %%
# Creating a bar plot for the 'Hba1c_level' column with x-axis based on 'Outcome'
fx = sns.barplot(data= df2, x= 'Outcome', y= 'Hba1c_level')
# Setting custom x-axis tick labels for better clarity
fx.set(title='Diabetes vs HbA1c Level')
# Setting title for the plot
fx.set_xticklabels(['No Diabetes', 'Diabetes'])
# Out:
# <ipython-input-254-3214eb3a347c>:6: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   fx.set_xticklabels(['No Diabetes', 'Diabetes'])
# [Text(0, 0, 'No Diabetes'), Text(1, 0, 'Diabetes')]

# %%
# Creating a box plot for the 'Hba1c_level' column with x-axis based on 'Outcome'
fx = sns.catplot(data= df2, x='Outcome', y= 'Hba1c_level', kind='box')
# Setting custom x-axis tick labels for better clarity and Setting title
fx.set(title='Diabetes vs HbA1c Level')
fx.set_xticklabels(['No Diabetes', 'Diabetes'])

# %% [markdown]
# The HbA1c test is a blood test that measures the average blood sugar level over the past 2-3 months. An HbA1c level of 6.5% or higher is considered to be diabetes.
#
# The boxplot shows that the median HbA1c level is higher in people with diabetes than in people without diabetes. The distribution of HbA1c levels is also wider in people with diabetes than in people without diabetes.
#
# Thus, we may conclude that the likelihood of developing diabetes rises with an increase in HbA1c levels.

# %%
# Creating a bar plot for the 'glucose' column with x-axis based on 'Outcome' using Seaborn barplot
fx = sns.barplot(data= df2, x='Outcome', y='glucose')
fx.set(title='Diabetes vs Blood Glucose Level')
fx.set_xticklabels(['No Diabetes', 'Diabetes'])
# Out:
# <ipython-input-256-ab2b2975e1cb>:4: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   fx.set_xticklabels(['No Diabetes', 'Diabetes'])
# [Text(0, 0, 'No Diabetes'), Text(1, 0, 'Diabetes')]

# %%
# Creating a box plot for the 'glucose' column with x-axis based on 'Outcome' using Seaborn catplot
fx = sns.catplot(data= df2, x='Outcome', y='glucose', kind='box')
fx.set(title='Diabetes vs Blood Glucose Level')
fx.set_xticklabels(['No Diabetes', 'Diabetes'])

# %% [markdown]
# The blood glucose level is a measure of the amount of glucose in the blood. A blood glucose level of 160 mg/dL or higher after fasting for at least 8 hours is considered to be diabetes which is median of the box plot.
#
# The boxplot also shows that the distribution of blood glucose levels is wider in people with diabetes than in people without diabetes. This means that there is a greater range of blood glucose levels in people with diabetes.

# %%
sns.jointplot(data= df2, x='Bloodpressure', y='Age', hue='Outcome', kind='scatter')

# %%
pairplot_columns = ['hypertension', 'heart_disease', 'Pregnancies', 'Bloodpressure', 'Outcome']

# Pair plot for selected columns
sns.pairplot(data=df2[pairplot_columns], hue='Outcome', kind='scatter')
plt.suptitle('Pair Plot of Variables with Outcome', y=1.02)
plt.show()

# %%
# Creating a box plot for the 'Bloodpressure' column with x-axis based on 'Outcome'
xx = sns.boxplot(x='Outcome', y='Bloodpressure', data=df2)
xx.set_title('Distribution of Blood Pressure')
# Out:
# Text(0.5, 1.0, 'Distribution of Blood Pressure')

# %% [markdown]
# Hypertension and Diabetes:
# - There appears to be some positive correlation between hypertension and diabetes. Individuals with diabetes tend to have a slightly higher prevalence of hypertension. This observation aligns with existing medical knowledge, as hypertension is recognized as a common comorbidity with diabetes.
#
# Blood Pressure and Diabetes:
# - The analysis suggests that having diabetes may increase the likelihood of elevated blood pressure. This finding supports the idea that diabetes and hypertension are interconnected, and the presence of one condition can influence the occurrence of the other. This relationship underscores the importance of monitoring and managing blood pressure in individuals with diabetes.
#
# Heart Disease and Diabetes:
# - The pair plot indicates a potential association between heart disease and diabetes, but the correlation may not be as clear as with hypertension and blood pressure. It's important to note that heart disease is a complex condition influenced by various factors beyond diabetes.
#
# Pregnancies and Diabetes:
# - While there is a range of pregnancies for both diabetes and non-diabetes groups, the higher number of pregnancies tends to be more prevalent in individuals with diabetes. This aligns with the known association between gestational diabetes and the number of pregnancies.

# %%
# Creating a box plot for the 'Age' column with x-axis based on 'smoking_history' and hue based on 'Outcome'
sns.boxplot(x='smoking_history', y='Age', hue='Outcome', data=df2, palette='Set3')
# Out:
# <Axes: xlabel='smoking_history', ylabel='Age'>

# %% [markdown]
# The boxplot shows that people who currently smoke are more likely to have diabetes than people who never smoked or who used to smoke(2nd and 3rd plot). This is because smoking increases the risk of developing diabetes in a number of ways.

# %% [markdown]
# # Conclusion

# %% [markdown]
# **Age and Diabetes:**
# - Effect: Diabetes prevalence increases with age.
# - Health Tip: Regular health check-ups and lifestyle adjustments become crucial with advancing age to manage diabetes risk.
#
# **BMI and Diabetes:**
# - Effect: Higher BMI correlates with diabetes.
# - Health Tip: Maintain a healthy BMI through a balanced diet and regular exercise to reduce diabetes risk.
#
# **HbA1c Levels:**
# - Effect: Higher HbA1c levels indicate a likelihood of diabetes.
# - Health Tip: Monitor and manage HbA1c levels through a diabetes-friendly diet and medication adherence.
#
# **Blood Glucose Levels:**
# - Effect: Elevated levels are associated with diabetes.
# - Health Tip: Adopt a low-sugar diet and stay physically active to regulate blood glucose.
#
# **Hypertension, Blood Pressure, and Diabetes:**
# - Effect: Positive correlation; diabetes increases likelihood of hypertension.
# - Health Tip: Manage blood pressure through a heart-healthy lifestyle to mitigate diabetes risk.
#
# **Heart Disease and Diabetes:**
# - Effect: Potential association; requires further investigation.
# - Health Tip: Prioritize heart-healthy habits, such as regular exercise and a balanced diet, to reduce overall health risks.
#
# **Smoking and Diabetes:**
# - Effect: Current smokers show higher likelihood of diabetes.
# - Health Tip: Quit smoking and adopt a smoke-free lifestyle to promote overall health and reduce diabetes risk.

# %% [markdown]
# # Problem Applicability

# %% [markdown]
# This relative comparison and assessment of different health factors concerning diabetes is very useful to establish risk predictor and key preventive health measures. Using the characteristics like age, BMI, HbA1c levels, blood glucose, hypertension, heart diseases and smoking, the healthcare professionals will have the focus on the prevention and early diagnosis of diabetes. The findings yielded by this study are valuable for creating the understanding of the populations needed for tailored health plans, increasing awareness of how to change lifestyles to avoid or control diabetes amid the populations at risk of multiple co-morbidities.

# %% [markdown]
# # **THANK YOU**
